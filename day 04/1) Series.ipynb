# %% [markdown]
# # Pandas Series

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# # Creating Series

# %%
labels = ['a', 'b', 'c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
pd.Series(d)  # when you pass dictionay you auto pass labels
# Out:
# a    10
# b    20
# c    30
# dtype: int64
