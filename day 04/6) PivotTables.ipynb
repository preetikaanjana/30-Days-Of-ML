# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# # Pivot Tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    853     94   John  January      Q1
# 1  2023-01-02       B   West    943     52   Mary  January      Q1
# 2  2023-01-03       C  North    542     60    Bob  January      Q1
# 3  2023-01-04       D  South    980     52  Alice  January      Q1
# 4  2023-01-05       A   East    872     31   John  January      Q1
# 5  2023-01-06       B   West    440     19   Mary  January      Q1
# 6  2023-01-07       C  North    479     52    Bob  January      Q1
# 7  2023-01-08       D  South    461     64  Alice  January      Q1
# 8  2023-01-09       A   East    590     29   John  January      Q1
# 9  2023-01-10       B   West    566     79   Mary  January      Q1
# 10 2023-01-11       C  North    500     38    Bob  January      Q1
# 11 2023-01-12       D  South    853     48  Alice  January      Q1
# 12 2023-01-13       A   East    128     72   John  January      Q1
# 13 2023-01-14       B   West    896     54   Mary  January      Q1
# 14 2023-01-15       C  North    385     57    Bob  January      Q1
# 15 2023-01-16       D  South    673     82  Alice  January      Q1
# 16 2023-01-17       A   East    892     55   John  January      Q1
# 17 2023-01-18       B   West    559     23   Mary  January      Q1
# 18 2023-01-19       C  North    899     33    Bob  January      Q1
# 19 2023-01-20       D  South    203     77  Alice  January      Q1

# %%
pd.pivot_table(df,values='Sales',index='Region',columns='Product')
# Out:
# Product      A      B      C      D
# Region
# East     667.0    NaN    NaN    NaN
# North      NaN    NaN  561.0    NaN
# South      NaN    NaN    NaN  634.0
# West       NaN  680.8    NaN    NaN

# %%
pd.pivot_table(df,values='Sales',index='Region',columns='Product',aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     853.0    NaN    NaN    NaN
# North      NaN    NaN  500.0    NaN
# South      NaN    NaN    NaN  673.0
# West       NaN  566.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2  # value must be numeric and region and coumns can be categorical
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     667.0    NaN    NaN    NaN  56.2   NaN   NaN   NaN
# North      NaN    NaN  561.0    NaN   NaN   NaN  48.0   NaN
# South      NaN    NaN    NaN  634.0   NaN   NaN   NaN  64.6
# West       NaN  680.8    NaN    NaN   NaN  45.4   NaN   NaN

# %% [markdown]
# # Cross Tabs

# %%
pd.crosstab(df['Region'],df['Product']) # for counting purpose
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
