# %%
import numpy as np
from scipy.stats import norm

# %%
sample = [172, 174, 168, 169, 171, 173, 175, 170, 169, 172] # we should use more than 30 sample we need to use ttest here but it is just for an example
population_mean = 170
population_std = 3
samp_mean = np.mean(sample)
n = len(sample)

# %%
z_score = (samp_mean - population_mean) / (population_std / np.sqrt(n))
z_score
# Out:
# 1.3703203194063098

# %%
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# %%
p_value
# Out:
# 0.17058693287143756

# %%
alpha = 0.05

if p_value < alpha:
    print("I will reject the null hypothesis")
else:
    print("i will accept the null hypothesis ")
# Out:
# i will accept the null hypothesis
